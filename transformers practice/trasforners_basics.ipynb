# %%
from transformers import pipeline

# %%
classifier = pipeline('sentiment-analysis')

# %%
res = classifier("This course sucks. waste of time")

# %%
print(res)

# %%
res = classifier("So upon Ayumi saying about what comes next with Toki, which means fixing the whole problem and move forward, I think it wasn't be so simple. I mean how can they manage in figuring out how to change anything (perception, aminosity, etc) between the two schools, and how are they going to handle it. Of course, everyone will try to accept this if said properly, but it won't be so easy due to the mishatred as well as the disdain from the girls. There will be bad gossips, discords, and, indeed, conflicts though it'll be minor and necessary in order to correct something like u said. However, since it is the Chidori's fault for the incident, perhaps the boy students will realize that and possibly deserved the harsh things for it. So we will see how all of this played out in this matter.")
print(res)

# %%
from huggingface_hub import notebook_login
from dotenv import load_dotenv
import os
load_dotenv()

Llama_hf_tk1 = os.getenv("HF_TOKEN")
notebook_login()

# %%
# !pip install accelerate

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-3.2-1B",dtype="auto",device_map="auto")
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-3.2-1B")

# %%
model_inputs = tokenizer(["The secret to baking a good cake is "], return_tensors="pt").to(model.device)

# %%
generated_ids = model.generate(**model_inputs, max_length=30)

# %%
tokenizer.batch_decode(generated_ids)[0]
